# %% [markdown]
# ## <span style="color:blue">Installations </span>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install wandb
#import wandb
#wandb.init()
# Out:
# wandb: Currently logged in as: aminedaghbouji. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220504_133400-3rv2zijb</code>
# Syncing run <strong><a href="https://wandb.ai/aminedaghbouji/uncategorized/runs/3rv2zijb" target="_blank">scruffy-looking-admiral-4</a></strong> to <a href="https://wandb.ai/aminedaghbouji/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/aminedaghbouji/uncategorized/runs/3rv2zijb?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# !pip install cltk

# %%
# !pip3 install nltk

# %%
# !pip install easyocr
# !pip install torch torchvision torchaudio
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.5.2.52

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %% [markdown]
# ## Importing libraries

# %%
#Main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statistics
import os
from numpy import random
import string
import re
# %matplotlib inline

#OCR
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np
import os

#Models testing
from collections import OrderedDict

#Pickle
import pickle

#NLTK
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import RegexpTokenizer,word_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
from nltk.corpus import stopwords
from nltk.stem.snowball import FrenchStemmer
from nltk import word_tokenize

#cltk
import cltk
from cltk.lemmatize.french.lemma import LemmaReplacer
from cltk.tokenize.word import WordTokenizer

#sklearn
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

#nlp
import spacy
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ## OCR

# %%
def image_to_text(crop_path):
  IMAGE_PATH = crop_path
  reader = easyocr.Reader(['fr'])
  result = reader.readtext(IMAGE_PATH , detail=0)

  ch=''
  for i in result:
    ch =ch+' '+i
  return(ch)

# %%
#5 64 49 63 50 67 68 72 73 74 75 71 70

# %%
# %cd /content/drive/MyDrive/PFE/yolov5/runs/detect/exp69/crops/section
# Out:
# /content/drive/MyDrive/PFE/yolov5/runs/detect/exp69/crops/section

# %% [markdown]
# **myCV**

# %%
import pytesseract as tess 
from PIL import Image

# %%
def pytesseractoutput():
    myCV = []
    for i in os.listdir("/content/drive/MyDrive/PFE/yolov5/runs/detect/exp69/crops/section") :
        myCV.append(tess.image_to_string('/content/drive/MyDrive/PFE/yolov5/runs/detect/exp69/crops/section/'+i))
    return(myCV)

# %% [markdown]
# **myCV2**

# %%
#myCV2
path = str(os.getcwd())
print(path)
myCV2 = []
myCV2 = OCR_function(path)
# Out:
# /content/drive/MyDrive/PFE/yolov5/runs/detect/exp63/crops/section

# %%
myCV2
# Out:
# [" Missionz: Développer des parties dune application d'assurance dans laquelle j'ai travaillé en tant que développeur full- stack (Python /Django). Jai travaillé à la fois coté admin - istrateur et côté client; développant des API et d'autres fonctionnalités intégrant également des interfaces util- isant HTML. bootstrap et jquery: Ycompris la gestion de base de données avec Postgres. Jai également appris et jai développé des tests unitaires pour chaque appli- cation due Django, Test   Unitaire;   Bootstrap;  JQuery,   Html, Swagger, Postgres, Docker; Gitlab, Jira Développeur full stack Fev 2020 Mai 2020",
# ...

# %% [markdown]
# ## <span style="color:green">Resampling the data (unused)</span>

# %% [markdown]
#  <span style="color:red">We notice that there is a big difference between churned and non-churned people so we will do a resampling</span>

# %%
from sklearn.utils import resample

data_majority = data[data.ChurnValue== 0]
data_minority = data[data.ChurnValue== 1]

data_minority_upsampled = resample(data_minority,
                                replace=True,
                                n_samples=5000,
                                random_state=123)

data_upsampled = pd.concat([data_majority, data_minority_upsampled])

print('Churn Count in Original Data: \n', data.ChurnValue.value_counts(), '\n')
print('New Churn Count: \n', data_upsampled.ChurnValue.value_counts())
# Out:
# Churn Count in Original Data:
#  0    5174
# 1    1869
# Name: ChurnValue, dtype: int64
#
# New Churn Count:
#  0    5174
# 1    5000
# Name: ChurnValue, dtype: int64

# %%
# Separate majority and minority classes
data_nbc_majority = data_nbc[data_nbc.iloc[:]==1]
data_nbc_minority = data_nbc[data_nbc.iloc[:]==0]
 
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    
                                 n_samples=1000)
#Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     
                                 n_samples=1000)
# Combine minority class with downsampled majority class
df_up_down_sampled = pd.concat([df_majority_downsampled, df_minority_upsampled])

# %%
from sklearn.utils import resample

data_majority = data_nbcc[data.ChurnValue== 0]
data_minority = data[data.ChurnValue== 1]

data_minority_upsampled = resample(data_minority,
                                replace=True,
                                n_samples=5000,
                                random_state=123)

data_upsampled = pd.concat([data_majority, data_minority_upsampled])

print('Churn Count in Original Data: \n', data.ChurnValue.value_counts(), '\n')
print('New Churn Count: \n', data_upsampled.ChurnValue.value_counts())

# %%
# !pip3 install multi-imbalance

# %%
from multi_imbalance.resampling.soup import SOUP

soup = SOUP(maj_int_min={
        'maj': [0, 1], # indices of majority classes
        'min': [2, 3, 4, 5] # indices of minority classes
    })
X_train_res, y_train_res = soup.fit_transform(X_train, y_train)
plot_visual_comparison_datasets(X_train, y_train, X_train_res, y_train_res, 'Glass', 'Resampled Glass')

# %%
sns.countplot(data_upsampled['ChurnValue'],label="Count")
plt.show()

# %%
#data=data_upsampled

# %%
data['PaymentMethod'].value_counts().plot.pie()
plt.show()

# %%
boxplot = data.boxplot(column=[ 'MonthlyCharges'])
plt.show()

# %%
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'],errors='coerce')
data['TotalCharges'] = data['TotalCharges'].astype("float")

# %% [markdown]
# # Classification algorithms

# %% [markdown]
# ## <span style="color:green">Reading Data </span>

# %%
data = pd.read_csv('/content/drive/MyDrive/PFE/dataset_27_avril/data1.csv')

# %% [markdown]
# ## Text preprocessing

# %%
def text_preprocessing_function(sentence):
  fr_stop_words = stopwords.words('french')
  sentence=str.lower(sentence)
  symb = []
  for i in string.punctuation:
    symb.append(i)
  tokenizer = WordTokenizer('french')
  tokens = tokenizer.tokenize(cleantext)
  filtered_words= [word for word in tokens if (word not in fr_stop_words and word not in symb)]
  return " ".join(filtered_words)

# %%
data['target'] = data_nbc['target'].apply(text_preprocessing_function)

# %%
data

# %% [markdown]
# ## Data Modeling preparation

# %%
def modeling_preparation_function():
  #Séparer les variables explicatives X/Classe y
  X=data_nbc.section
  y=data_nbc.target
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)
  return X_train, X_test, y_train, y_test

# %%
my_tags = ['contact','profil','formation','experience','projets','competences','langues']

# %%
X_train, X_test, y_train, y_test = modeling_preparation_function()

# %% [markdown]
# ## Naives Bayes

# %%
def naive_bayes_function():
  nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
  nb.fit(X_train,y_train)


  y_pred = nb.predict(X_test)

  #print('accuracy %s' % accuracy_score(y_pred, y_test))
  #print(classification_report(y_test, y_pred,target_names=my_tags))
  return nb

# %%
nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(X_train,y_train)


y_pred = nb.predict(X_test)
print("Naive Bayes Accuracy :")
print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=my_tags))
# Out:
# Naive Bayes Accuracy :
# accuracy 0.6994535519125683
#               precision    recall  f1-score   support
#
#      contact       0.00      0.00      0.00        11
#       profil       0.90      0.69      0.78        26
#    formation       1.00      0.96      0.98        28
#   experience       0.32      0.96      0.48        24
#      projets       0.89      0.94      0.91        33
#  competences       1.00      0.96      0.98        23
#      langues       0.88      0.35      0.50        20
#       autres       0.00      0.00      0.00        18
#
#     accuracy                           0.70       183
#    macro avg       0.62      0.61      0.58       183
# weighted avg       0.70      0.70      0.67       183
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.metrics import confusion_matrix

# We predict target values
Y_predict1 = nb.predict(X_test)
# The confusion matrix
nbcla_cm = confusion_matrix(y_test, Y_predict1)
f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(nbcla_cm, annot=True, linewidth=0.7, linecolor='black', fmt='g', ax=ax, cmap="BuPu")
plt.title('Naive Bayes Classification Confusion Matrix')
plt.xlabel('Y predict')
plt.ylabel('Y test')
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, confusion_matrix
preds1 = Y_predict1
# XGBoost produces confidence scores for each value, rather than definite predictions
# so if we want to use metrics like accuracy or f1-score, we have to round those values
#hard_preds1 = preds1.round()

print("Naives Bayes:")
print('Accuracy:', accuracy_score(y_test, preds1))
print('f1-score:', f1_score(y_test, preds1, average='micro'))
print('Precision:', precision_score(y_test, preds1, average='micro'))
print('Recall:', recall_score(y_test, preds1, average='micro'))
#print('ROC AUC:', roc_auc_score(y_test, preds1, average='micro'))
# Out:
# Naives Bayes:
# Accuracy: 0.6994535519125683
# f1-score: 0.6994535519125683
# Precision: 0.6994535519125683
# Recall: 0.6994535519125683

# %% [markdown]
# ## Linear Support Vector Machine

# %%
def svm_function():
  sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
  sgd.fit(X_train, y_train)


  y_pred = sgd.predict(X_test)

  #print('accuracy %s' % accuracy_score(y_pred, y_test))
  #print(classification_report(y_test, y_pred,target_names=my_tags))
  return sgd

# %%
sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
sgd.fit(X_train, y_train)


y_pred = sgd.predict(X_test)
print("SVM accuracy : ")
print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=my_tags))
# Out:
# SVM accuracy :
# accuracy 0.8797814207650273
#               precision    recall  f1-score   support
#
#      contact       1.00      0.55      0.71        11
#       profil       0.88      0.88      0.88        26
#    formation       0.97      1.00      0.98        28
#   experience       0.69      0.83      0.75        24
#      projets       0.89      1.00      0.94        33
#  competences       1.00      0.96      0.98        23
#      langues       1.00      0.80      0.89        20
#       autres       0.72      0.72      0.72        18
#
#     accuracy                           0.88       183
#    macro avg       0.89      0.84      0.86       183
# weighted avg       0.89      0.88      0.88       183

# %% [markdown]
# ## Logistic Regression

# %%
def logistic_regression_function():
  logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
  logreg.fit(X_train, y_train)


  y_pred = logreg.predict(X_test)

  #print('accuracy %s' % accuracy_score(y_pred, y_test))
  #print(classification_report(y_test, y_pred,target_names=my_tags))
  return logreg

# %%
logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
logreg.fit(X_train, y_train)


y_pred = logreg.predict(X_test)
print("Logistic regression accuracy :")
print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=my_tags))

# %% [markdown]
# ## Models testing

# %%
CV_dict_predicted1
# Out:
# OrderedDict([('nom_prenom', ''),
#              ('email', ''),
#              ('phone_number', ''),
#              ('contact',
#               ' +216 90753245 rayentouaiti@esprit.tn in www. linkedin comlin/touaiti-rayen- b42425200/ rue des abricotiers bardo tunis'),
#              ('titre', ''),
#              ('profil', ''),
#              ('langues',
#               ' langues français anglais courant courant arabe langue natale'),
#              ('formation',
#               ' education master professionnel en business analytics esprit school of business 09/2019 07/2021 licence appliquée en ingénierie économique et financière institut supérieure de gestion de tunis 09/2015 07/2019 baccalauréat scientifique en mathématiques lycée de bousalem vie associative marketing et communication club radio isg 2016-2017 sponsoring et évènementiel jci bousalem 2015-2016'),
#              ('projets',
# ...

# %%
#New
cv_dict1 = OrderedDict([('contact',
              ' 9; rue de confort el wardia 1 tunis, 1009 tunisie +216 28 01 55 35 abdelghafarlinda@gmail com in linkedin comlinllinda-abdelghaffar ~063b5a1b9'),
              ('profil',
              'présentation je suis appréciée pour mon aptitude à évaluer les besoins opérationnels et à trouver des solutions permettant de réduire les coûts, daugmenter les revenus et la satisfaction de la clientèle.'),
              ('langues',
              ' langues arabe francais anglais espagnole'),
              ("formation",
              'formations et certifications formation en ligne facebook ads novembre 2020 formation google analytics pour les débutants google analytics academy novembre 2021 formation en marketing digital espima business school septembre 2020 certificat de langue anglais business intermédiaire interactive language center janvier 2018 etudes mastère professionnel en communication marketing et digitale faculté des sciences économiques et de gestion de tunis juillet 2021 licence fondamentale en marketing faculté des sciences économiques et de gestion de tunis juin 2019 baccalauréat en economie et gestion lycée rue de russie tunis juin 2015'),
              ('projets',
              'projets académiques etude qualitative étudequalitative pour ledéveloppement dune application mobile pour les événements culturels organisés par les associations humanitaires et estudiantines. design thinking élaborer une solution pour la digitalisation de la municipalité tunisienne marketing international analyse de la stratégie du marketing international optée par decathlon intelligence marketing le rôle des applications mobiles pour les consommateurs'),
              ('experience',
              'expériences professionnelles stage pfe mastère professionnel elaboration et exécution dune stratégie de communication digitale; talys tunis mars 2021-juin 2021 définir les objectifs stratégiques de communication benchmarking définir la cible des actions digitales. mettre en place une stratégie du contenu. agent de service client -jumia; tunis juin 2019-octobre 2019 traitement de réclamations client réaliser des ventes stage dété -biat, tunis juillet 2018-aout 2018 extrait de compte demande et de livraison de chéquiers réception et de livraison des cartes bancaires_ relevé bancaire stage dété-biat tunis juin 2021 versement et retrait argent vérification les états de lettres de change'),
              ('competences', ' outils adobe spark wordpress canva mailchimp pack office compétences marketing stratégique. etude de marché. maitrise des outils de communication digitale elaboration stratégie de communication digitale- création de contenu. mesurer laperformance des actions de communication digitale. gérer les sites web gérer les relations avec les prestataires web.')
             ])

# %%
dict1_values = list(CV_dict_predicted1.values())
dict2_values = list(cv_dict1.values())
l = len(dict1_values)
for j in range(0,l):
  j = j.rstrip()
  print("1",dict1_values[j].lstrip())
  print("2",dict2_values[j].lstrip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-7cad87ead355> in <module>()
# ----> 1 dict1_values = list(CV_dict_predicted1.values().rstrip())
#       2 dict2_values = list(cv_dict1.values().rstrip())
#       3 l = len(dict1_values)
#       4 for j in range(0,l):
#       5     print("1",dict1_values[j].lstrip())
#
# AttributeError: 'odict_values' object has no attribute 'rstrip'

# %%
def prediction_precision_function(dict1,dict2):
  dict1_values = list(dict1.values())
  dict2_values = list(dict2.values())
  k=0
  l = len(dict1_values)
  for j in range(1,l):
    if dict1_values[j].lstrip().rstrip() == dict2_values[j].lstrip().rstrip():
      k+=1
  return (k/l)*100

# %%
one_item_precision = prediction_precision_function(CV_dict_predicted1,cv_dict1)
one_item_precision
# Out:
# 42.857142857142854

# %%
predicted_dict = []
true_dict = []
predicted_dict,true_dict=prediction_precision(CV_dict_predicted1,cv_dict1)

# %%
print("predicted dict :", predicted_dict)
print("True dict :", true_dict)
# Out:
# predicted dict : [odict_values(['langues', 'competences', 'formation', 'experience', 'formation', 'contact', 'experience', 'experience', 'experience'])]
# True dict : [odict_values(['langues', 'competences', 'formation', 'profil', 'formation', 'contact', 'competences', 'experience', 'projets'])]

# %%
#list = ['+33 7 00 55 51 56 gregoire.givry@gmail.com 67200 Strasbourg']
#list = ['Compétences exceptionnelles en communication et en réseautage Esprit déquipe et travail autonome Capacité à travailler sous pression et à exécuter plusieurs tâches à la fois Capacité à suivre des instructions et à obtenir des résultats de qualité']
#list = ['12 Singes, assistant marketing Juin 2019 - Jan 2020 Maintenir et organiser de nombreux dossiers de bureau Tenir constamment à jour les listes de contacts et les listes de diffusion de lentreprise Surveiller la couverture de presse Markos, assistant marketing Juillet 2018 - Juillet 2019 Gestion de la présence en ligne de la société -Mise à jour régulière du site Web de la société et de divers comptes de médias sociaux Suivi des campagnes marketing en cours Préparation de présentations pour les clients potentiels']
#list = ['12, rue Moret, 75001 Paris thomassaumur@gmail.fr 01 23 89 98 74 /thomassaumur']
list=['turque niveau b1']
#list=['Licence en marketing à lUniversité de Condorcet 2018']
#list = ['Étudiant en DUT commerce ayant une grande capacité d’organisation et de prise d’initiative ainsi que de  en service clientèle et en vente. Je souhaite rejoindre l’équipe d’Intermarché pour l’aider à atteindre ses objectifs de rendement en rayons et d’organisation en réserve.']
#list = ['Priorisation des tâches autonomie Relation client Gestion des stocks']
#list = ['Allemand Courant (niveau C1) Anglais Intermédiaire (niveau B2)']
#list = ['2020–2022 (en cours) DUT Techniques de Commercialisation IUT Robert Schuman, Strasbourg Première année LV1 Anglais, LV2 allemand Matières préférées : Logistique, Marketing opérationnel, Négociation, Allemand Réalisations : Major de promo en Logistique aux S1 et S2 Participant au 4L Trophy 2017–2020 Bac STMG option Marketing Lycée René Cassin, Strasbourg LV1 Anglais, LV2 allemand Matières préférées : Marketing, Sciences de gestion, Allemand Réalisations : Mention Bien Prix du concours d’éloquence du lycée 2018']
#list = ['Décembre 2016 Caisse d’Épargne, Ostwald stage Réceptionniste d’une semaine Accueillir et rediriger les clients Prendre les rendez-vous Renseigner la clientèle concernant les offres annexes (téléphonie, assurances)']
#list = ['Football américain (remplaçant au club Le Minotaure) Littérature et philosophie antique']
list=list*128
# create series form a list
ser = pd.Series(list)

# %%
print("Naives Bayes Prediction:"+str(nb.predict(ser)[0]))
print("SVM Prediction:"+str(sgd.predict(ser)[0]))
print("Logitic Regression Prediction:"+str(logreg.predict(ser)[0]))
# Out:
# Naives Bayes Prediction:langues
# SVM Prediction:langues
# Logitic Regression Prediction:langues
